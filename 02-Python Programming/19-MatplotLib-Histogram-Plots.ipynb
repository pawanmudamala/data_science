# %% [markdown]
# # Histograms with Matplotlib in Python

# %%
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd

# %%
# %matplotlib inline

# %%
plt.style.use("fivethirtyeight")

# %% [markdown]
# ## How to Plot Histograms ?

# %%
data=np.random.randn(1000)
len(data)
# Out:
# 1000

# %%
a = plt.hist(data)

# %%
plt.hist(data)
plt.title("My Histograms")
plt.xlabel("Values")
plt.ylabel("Frequencies")
# Out:
# Text(0, 0.5, 'Frequencies')

# %%
plt.hist(data, edgecolor="black")
plt.title("My Histograms")
plt.xlabel("Values")
plt.ylabel("Frequencies")
# Out:
# Text(0, 0.5, 'Frequencies')

# %%
plt.hist(data, edgecolor="black", bins=10)
plt.title("My Histograms")
plt.xlabel("Values")
plt.ylabel("Frequencies")
# Out:
# Text(0, 0.5, 'Frequencies')

# %%
bins=[-3,-2,-1,0,1,2,3]

# %%
plt.hist(data, edgecolor="black", bins=bins)
plt.title("My Histograms")
plt.xlabel("Values")
plt.ylabel("Frequencies")
# Out:
# Text(0, 0.5, 'Frequencies')

# %%
median=np.median(data)

# %%
plt.hist(data, edgecolor="black", bins=bins)
plt.title("My Histograms")
plt.xlabel("Values")
plt.ylabel("Frequencies")
plt.axvline(median, color="red")

# %% [markdown]
# ## Application with real data set

# %%
import os
os.chdir('C:\\Users\\halad\\Documents\\GL\\My Training on DS and ML\\01 - Introduction\\Notebooks\\')

# %%
movies=pd.read_csv("datasets/imdbratings.txt")

# %%
movies.head()
# Out:
#    star_rating                     title content_rating   genre  duration  \
# 0          9.3  The Shawshank Redemption              R   Crime       142
# 1          9.2             The Godfather              R   Crime       175
# 2          9.1    The Godfather: Part II              R   Crime       200
# 3          9.0           The Dark Knight          PG-13  Action       152
# 4          8.9              Pulp Fiction              R   Crime       154
#
#                                          actors_list
# 0  [u'Tim Robbins', u'Morgan Freeman', u'Bob Gunt...
# 1    [u'Marlon Brando', u'Al Pacino', u'James Caan']
# 2  [u'Al Pacino', u'Robert De Niro', u'Robert Duv...
# 3  [u'Christian Bale', u'Heath Ledger', u'Aaron E...
# 4  [u'John Travolta', u'Uma Thurman', u'Samuel L....

# %%
plt.hist(movies.duration)
# Out:
# (array([ 25., 168., 301., 259., 111.,  66.,  27.,  14.,   5.,   3.]),
#  array([ 64. ,  81.8,  99.6, 117.4, 135.2, 153. , 170.8, 188.6, 206.4,
#         224.2, 242. ]),
#  <BarContainer object of 10 artists>)

# %%
plt.hist(movies.duration, edgecolor="black", color="m")
# Out:
# (array([ 25., 168., 301., 259., 111.,  66.,  27.,  14.,   5.,   3.]),
#  array([ 64. ,  81.8,  99.6, 117.4, 135.2, 153. , 170.8, 188.6, 206.4,
#         224.2, 242. ]),
#  <BarContainer object of 10 artists>)

# %%
bins=np.arange(70,200,10)

# %%
plt.hist(movies.duration, edgecolor="black",color="m", bins=bins)
plt.xticks(bins)
# Out:
# ([<matplotlib.axis.XTick at 0x1ff7e01e160>,
#   <matplotlib.axis.XTick at 0x1ff7e01e130>,
#   <matplotlib.axis.XTick at 0x1ff7e012820>,
#   <matplotlib.axis.XTick at 0x1ff7e062310>,
#   <matplotlib.axis.XTick at 0x1ff7e062a60>,
#   <matplotlib.axis.XTick at 0x1ff7e0671f0>,
#   <matplotlib.axis.XTick at 0x1ff7e067940>,
#   <matplotlib.axis.XTick at 0x1ff7e062ac0>,
#   <matplotlib.axis.XTick at 0x1ff7e0679a0>,
#   <matplotlib.axis.XTick at 0x1ff7e06d430>,
#   <matplotlib.axis.XTick at 0x1ff7e06db80>,
#   <matplotlib.axis.XTick at 0x1ff7e073310>,
#   <matplotlib.axis.XTick at 0x1ff7e073a60>],
#  [Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, '')])

# %%
plt.hist(movies.duration, edgecolor="black",color="m", bins=bins)
plt.xticks(bins)
plt.title("Histograms of movie durations in imdb")
plt.xlabel("Durations")
plt.ylabel("Frequencies")
# Out:
# Text(0, 0.5, 'Frequencies')
