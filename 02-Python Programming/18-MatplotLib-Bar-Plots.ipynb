# %% [markdown]
# # Bar Plot with Matplotlib in Python

# %%
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd

# %%
# %matplotlib inline

# %%
plt.style.use("fivethirtyeight")

# %%
Math = np.random.randint(50,100,7)
Stat = np.random.randint(50,100,7)
CS   = np.random.randint(50,100,7)

# %%
classes = list("ABCDEFG")
classes
# Out:
# ['A', 'B', 'C', 'D', 'E', 'F', 'G']

# %%
plt.plot(classes, Math, label="Math Avg")
plt.plot(classes, Stat, label="Stat Avg")
plt.plot(classes, CS, label="CS Avg")
plt.legend()
plt.title("Average of Lessons")
plt.xlabel("Classes")
plt.ylabel("Averages")
# Out:
# Text(0, 0.5, 'Averages')

# %%
plt.bar(classes, Math, label="Math Avg")
plt.bar(classes, Stat, label="Stat Avg")
plt.bar(classes, CS, label="CS Avg")
plt.legend()
plt.title("Average of Lessons")
plt.xlabel("Classes")
plt.ylabel("Averages")
# Out:
# Text(0, 0.5, 'Averages')

# %%
x_indeks=np.arange(len(classes))
x_indeks
# Out:
# array([0, 1, 2, 3, 4, 5, 6])

# %%
x=0.25
plt.bar(x_indeks-x, Math, label="Math Avg")
plt.bar(x_indeks, Stat, label="Stat Avg")
plt.bar(x_indeks+x, CS, label="CS Avg")
plt.legend()
plt.title("Average of Lessons")
plt.xlabel("Classes")
plt.ylabel("Averages")
# Out:
# Text(0, 0.5, 'Averages')

# %%
x
# Out:
# 0.25

# %%
plt.bar(x_indeks-x,Math,width=x,label="Math Avg")
plt.bar(x_indeks,Stat,width=x,label="Stat Avg")
plt.bar(x_indeks+x, CS, width=x, label="CS Avg")
plt.legend()
plt.title("Average of Lessons")
plt.xlabel("Classes")
plt.ylabel("Averages")
# Out:
# Text(0, 0.5, 'Averages')

# %%
plt.bar(x_indeks-x,Math,width=x,label="Math Avg")
plt.bar(x_indeks, Stat, width=x,label="Stat Avg")
plt.bar(x_indeks+x, CS, width=x, label="CS Avg")
plt.legend()
plt.title("Average of Lessons")
plt.xlabel("Classes")
plt.ylabel("Averages")
plt.xticks(ticks=x_indeks, labels=classes)
# Out:
# ([<matplotlib.axis.XTick at 0x191f77261c0>,
#   <matplotlib.axis.XTick at 0x191f7726190>,
#   <matplotlib.axis.XTick at 0x191f75d3f70>,
#   <matplotlib.axis.XTick at 0x191f7780be0>,
#   <matplotlib.axis.XTick at 0x191f778b370>,
#   <matplotlib.axis.XTick at 0x191f77809a0>,
#   <matplotlib.axis.XTick at 0x191f778bc70>],
#  [Text(0, 0, 'A'),
#   Text(1, 0, 'B'),
#   Text(2, 0, 'C'),
#   Text(3, 0, 'D'),
#   Text(4, 0, 'E'),
#   Text(5, 0, 'F'),
#   Text(6, 0, 'G')])

# %% [markdown]
# ## Error Bar
# Error Bars help to indicate estimated error or uncertainty to give a general sense of how precise a measurement is.

# %%
x=np.linspace(0,10,30)
x
# Out:
# array([ 0.        ,  0.34482759,  0.68965517,  1.03448276,  1.37931034,
#         1.72413793,  2.06896552,  2.4137931 ,  2.75862069,  3.10344828,
#         3.44827586,  3.79310345,  4.13793103,  4.48275862,  4.82758621,
#         5.17241379,  5.51724138,  5.86206897,  6.20689655,  6.55172414,
#         6.89655172,  7.24137931,  7.5862069 ,  7.93103448,  8.27586207,
#         8.62068966,  8.96551724,  9.31034483,  9.65517241, 10.        ])

# %%
y=np.random.randint(0,5,30)
y
# Out:
# array([3, 1, 2, 3, 2, 0, 4, 0, 1, 3, 2, 1, 2, 3, 3, 3, 4, 4, 2, 4, 1, 0,
#        0, 1, 3, 0, 1, 3, 1, 3])

# %%
plt.plot(x,y,"bo")

# %%
plt.plot(x,y,"bo")
plt.errorbar(x,y,yerr=1, fmt=".k")
# Out:
# <ErrorbarContainer object of 3 artists>

# %%
plt.plot(x,y,"bo")
plt.errorbar(x,y,xerr=1, fmt=".k")
# Out:
# <ErrorbarContainer object of 3 artists>

# %%
plt.errorbar(x, y, 
             yerr=1, 
             fmt='bo', 
             ecolor='red', 
             elinewidth=2, 
             capsize=0)
# Out:
# <ErrorbarContainer object of 3 artists>

# %% [markdown]
# ## Bar Graph with Error Bars

# %%
from sklearn.datasets import load_iris

# %%
iris = load_iris()

# %%
mean = np.mean(iris.data, axis=0)
sd   = np.std(iris.data, axis=0)

# %%
interval = range(4)

# %%
plt.barh(interval ,mean, color="b",xerr=sd, alpha=0.7, align="center")
# Out:
# <BarContainer object of 4 artists>

# %%
plt.barh(interval ,mean, color="b",xerr=sd, alpha=0.7, align="center")
plt.title('Horizontal Bars')
# Out:
# Text(0.5, 1.0, 'Horizontal Bars')

# %%
plt.barh(interval ,mean, color="b", xerr=sd, alpha=0.7, align="center")
plt.title('Horizontal Bars')
plt.yticks(interval, iris.feature_names)
# Out:
# ([<matplotlib.axis.YTick at 0x191fa884640>,
#   <matplotlib.axis.YTick at 0x191fa87ee80>,
#   <matplotlib.axis.YTick at 0x191fa87e370>,
#   <matplotlib.axis.YTick at 0x191fa8b2dc0>],
#  [Text(0, 0, 'sepal length (cm)'),
#   Text(0, 1, 'sepal width (cm)'),
#   Text(0, 2, 'petal length (cm)'),
#   Text(0, 3, 'petal width (cm)')])

# %%
plt.bar(interval, mean, color="m", yerr=sd, alpha=0.7, align="center")
plt.title('Vertical Bars')
# Out:
# Text(0.5, 1.0, 'Vertical Bars')

# %%
plt.bar(interval, mean, color="m", yerr=sd, alpha=0.7, align="center")
plt.title('Vertical Bars')
plt.xticks(interval, iris.feature_names,rotation=90)
# Out:
# ([<matplotlib.axis.XTick at 0x191fa949e50>,
#   <matplotlib.axis.XTick at 0x191fa949e20>,
#   <matplotlib.axis.XTick at 0x191fa949550>,
#   <matplotlib.axis.XTick at 0x191faaea610>],
#  [Text(0, 0, 'sepal length (cm)'),
#   Text(1, 0, 'sepal width (cm)'),
#   Text(2, 0, 'petal length (cm)'),
#   Text(3, 0, 'petal width (cm)')])

# %%
plt.bar(interval, mean, color="m", yerr=sd, alpha=0.7, width=0.5, align="center")
plt.title('Vertical Bars')
plt.xticks(interval,iris.feature_names, rotation=70);
