# %% [markdown]
# ### Dataframe Basic Functionalities

# %% [markdown]
# <div>
# <img src="attachment:image-2.png" width="500"/>
# </div>

# %%
import pandas as pd

# %% [markdown]
# ### Lets create a sample Data Frame

# %%
data={"name":["Bill","Tom","Tim","John","Alex","Vanessa","Kate"],      
      "score":[90,80,85,75,95,60,65],      
      "sport":["Wrestling","Football","Skiing","Swimming","Tennis",
               "Karete","Surfing"],      
      "sex":["M","M","M","M","F","F","F"]}

df = pd.DataFrame(data)
df
# Out:
#       name  score      sport sex
# 0     Bill     90  Wrestling   M
# 1      Tom     80   Football   M
# 2      Tim     85     Skiing   M
# 3     John     75   Swimming   M
# 4     Alex     95     Tennis   F
# 5  Vanessa     60     Karete   F
# 6     Kate     65    Surfing   F

# %% [markdown]
# ### 1 - T - Transposes rows and columns.

# %%
df.T
# Out:
#                0         1       2         3       4        5        6
# name        Bill       Tom     Tim      John    Alex  Vanessa     Kate
# score         90        80      85        75      95       60       65
# sport  Wrestling  Football  Skiing  Swimming  Tennis   Karete  Surfing
# sex            M         M       M         M       F        F        F

# %% [markdown]
# ### 2 - axes - Returns a list with the row axis labels and column axis labels as the only members.

# %%
df.axes
# Out:
# [RangeIndex(start=0, stop=7, step=1),
#  Index(['name', 'score', 'sport', 'sex'], dtype='object')]

# %% [markdown]
# ### 3 - dtypes - Returns the dtypes in this object.

# %%
df.dtypes
# Out:
# name     object
# score     int64
# sport    object
# sex      object
# dtype: object

# %% [markdown]
# ### 4 - empty - True if NDFrame is entirely empty [no items]; if any of the axes are of length 0.

# %%
df.empty
# Out:
# False

# %%
empry_df = pd.DataFrame()
empry_df
# Out:
# Empty DataFrame
# Columns: []
# Index: []

# %%
empry_df.empty
# Out:
# True

# %% [markdown]
# ### 5 - ndim - Number of axes / array dimensions.

# %%
df.ndim
# Out:
# 2

# %% [markdown]
# ### 6 - shape - Returns a tuple representing the dimensionality of the DataFrame.

# %%
df.shape
# Out:
# (7, 4)

# %% [markdown]
# ### 7 - size - Number of elements in the NDFrame.

# %%
df.size
# Out:
# 28

# %% [markdown]
# ### 8 - values - Numpy representation of NDFrame.

# %%
df.values
# Out:
# array([['Bill', 90, 'Wrestling', 'M'],
#        ['Tom', 80, 'Football', 'M'],
#        ['Tim', 85, 'Skiing', 'M'],
#        ['John', 75, 'Swimming', 'M'],
#        ['Alex', 95, 'Tennis', 'F'],
#        ['Vanessa', 60, 'Karete', 'F'],
#        ['Kate', 65, 'Surfing', 'F']], dtype=object)

# %%
values = df.values
type(values)
# Out:
# numpy.ndarray

# %% [markdown]
# #### - Accessing rows

# %%
values[0]
# Out:
# array(['Bill', 90, 'Wrestling', 'M'], dtype=object)

# %%
values[-1]
# Out:
# array(['Kate', 65, 'Surfing', 'F'], dtype=object)

# %%
values[[1,2,3]]
# Out:
# array([['Tom', 80, 'Football', 'M'],
#        ['Tim', 85, 'Skiing', 'M'],
#        ['John', 75, 'Swimming', 'M']], dtype=object)

# %%
values[0:3,:]
# Out:
# array([['Bill', 90, 'Wrestling', 'M'],
#        ['Tom', 80, 'Football', 'M'],
#        ['Tim', 85, 'Skiing', 'M']], dtype=object)

# %% [markdown]
# #### - Accessing columns

# %%
values[:,0]
# Out:
# array(['Bill', 'Tom', 'Tim', 'John', 'Alex', 'Vanessa', 'Kate'],
#       dtype=object)

# %%
values[:,1]
# Out:
# array([90, 80, 85, 75, 95, 60, 65], dtype=object)

# %%
values[:,0:2]
# Out:
# array([['Bill', 90],
#        ['Tom', 80],
#        ['Tim', 85],
#        ['John', 75],
#        ['Alex', 95],
#        ['Vanessa', 60],
#        ['Kate', 65]], dtype=object)

# %% [markdown]
# ### 9 - head() - To view the first n rows of the DF

# %%
df.head(3)
# Out:
#    name  score      sport sex
# 0  Bill     90  Wrestling   M
# 1   Tom     80   Football   M
# 2   Tim     85     Skiing   M

# %% [markdown]
# ### 10 - tail() - To view the last n rows of the DF

# %%
df.tail()
# Out:
#       name  score     sport sex
# 2      Tim     85    Skiing   M
# 3     John     75  Swimming   M
# 4     Alex     95    Tennis   F
# 5  Vanessa     60    Karete   F
# 6     Kate     65   Surfing   F
